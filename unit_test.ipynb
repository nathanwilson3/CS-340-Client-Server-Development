# %%
import unittest
from crud_module import AnimalShelter

class TestAnimalShelter(unittest.TestCase):
    
    @classmethod
    def setUpClass(cls):
        cls.shelter = AnimalShelter(
            user='aacuser',
            password='SNHU1234',
            host='nv-desktop-services.apporto.com',
            port= 31992,
            db='AAC'
            collection='animals'
        )
        cls.test_data = {"animal_id": "A123458", "name": "Max", "species": "Dog", "age": 2, "adopted": False}
        
        def test_create(sefl):
            result = sefl.shelter.create(self.test_data)
            self.assertTrue(result)
            
        def test_read(self):
            self.shelter.create(self.test_data)
            result = sefl.shelter.read({"animal_id": "A123458"})
            self.assetEqual(len(result), 1)
            self.assetEqual(result[0]["name"], "Max")
            
if __name__ == '__main__':
    unittest.main(argv=[''], verbosity=2, exit=False)
# Out:
#   Input In [2]
#     collection='animals'
#     ^
# SyntaxError: invalid syntax

# %%
import unittest
from crud_module import AnimalShelter

class TestAnimalShelter(unittest.TestCase):
    
    @classmethod
    def setUpClass(cls):
        cls.shelter = AnimalShelter(
            user='aacuser',
            password='SNHU1234',
            host='nv-desktop-services.apporto.com',
            port=31992,
            db='AAC',
            collection='animals'
        )
        cls.test_data = {"animal_id": "A123458", "name": "Max", "species": "Dog", "age": 2, "adopted": False}
        
    def test_create(self):
        result = self.shelter.create(self.test_data)
        self.assertTrue(result)
            
    def test_read(self):
        self.shelter.create(self.test_data)
        result = self.shelter.read({"animal_id": "A123458"})
        self.assertEqual(len(result), 1)
        self.assertEqual(result[0]["name"], "Max")
            
if __name__ == '__main__':
    unittest.main(argv=[''], verbosity=2, exit=False)
# Out:
# test_create (__main__.TestAnimalShelter) ... ok
# test_read (__main__.TestAnimalShelter) ... ERROR
#
# ======================================================================
# ERROR: test_read (__main__.TestAnimalShelter)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/tmp/ipykernel_1525515/2946727884.py", line 23, in test_read
#     self.shelter.create(self.test_data)
#   File "/home/nathanwilson3_snhu/Documents/crud_module.py", line 16, in create
#     result = self.collection.insert_one(data)
#   File "/usr/local/anaconda/lib/python3.9/site-packages/pymongo/collection.py", line 705, in insert_one
#     self._insert(document,
#   File "/usr/local/anaconda/lib/python3.9/site-packages/pymongo/collection.py", line 620, in _insert
#     return self._insert_one(
#   File "/usr/local/anaconda/lib/python3.9/site-packages/pymongo/collection.py", line 609, in _insert_one
#     self.__database.client._retryable_write(
#   File "/usr/local/anaconda/lib/python3.9/site-packages/pymongo/mongo_client.py", line 1552, in _retryable_write
#     return self._retry_with_session(retryable, func, s, None)
#   File "/usr/local/anaconda/lib/python3.9/site-packages/pymongo/mongo_client.py", line 1438, in _retry_with_session
#     return self._retry_internal(retryable, func, session, bulk)
#   File "/usr/local/anaconda/lib/python3.9/site-packages/pymongo/mongo_client.py", line 1470, in _retry_internal
#     return func(session, sock_info, retryable)
#   File "/usr/local/anaconda/lib/python3.9/site-packages/pymongo/collection.py", line 607, in _insert_command
#     _check_write_command_response(result)
#   File "/usr/local/anaconda/lib/python3.9/site-packages/pymongo/helpers.py", line 229, in _check_write_command_response
#     _raise_last_write_error(write_errors)
#   File "/usr/local/anaconda/lib/python3.9/site-packages/pymongo/helpers.py", line 210, in _raise_last_write_error
#     raise DuplicateKeyError(error.get("errmsg"), 11000, error)
# pymongo.errors.DuplicateKeyError: E11000 duplicate key error collection: AAC.animals index: _id_ dup key: { _id: ObjectId('665d6298eaff523a2ddb8845') }, full error: {'index': 0, 'code': 11000, 'errmsg': "E11000 duplicate key error collection: AAC.animals index: _id_ dup key: { _id: ObjectId('665d6298eaff523a2ddb8845') }", 'keyPattern': {'_id': 1}, 'keyValue': {'_id': ObjectId('665d6298eaff523a2ddb8845')}}
#
# ----------------------------------------------------------------------
# Ran 2 tests in 0.446s
#
# FAILED (errors=1)

# %%
import unittest
from crud_module import AnimalShelter
from bson.objectid import ObjectId

class TestAnimalShelter(unittest.TestCase):
    
    @classmethod
    def setUpClass(cls):
        cls.shelter = AnimalShelter(
            user='aacuser',
            password='SNHU1234',
            host='nv-desktop-services.apporto.com',
            port=31992,
            db='AAC',
            collection='animals'
        )
        cls.test_data = {"animal_id": "A123458", "name": "Max", "species": "Dog", "age": 2, "adopted": False}
        
    def setUp(self):
        # Ensure the test data has a unique _id
        self.test_data["_id"] = ObjectId()

    def test_create(self):
        result = self.shelter.create(self.test_data)
        self.assertTrue(result)
            
    def test_read(self):
        self.shelter.create(self.test_data)
        result = self.shelter.read({"animal_id": "A123458"})
        self.assertEqual(len(result), 1)
        self.assertEqual(result[0]["name"], "Max")
            
if __name__ == '__main__':
    unittest.main(argv=[''], verbosity=2, exit=False)
# Out:
# test_create (__main__.TestAnimalShelter) ... ok
# test_read (__main__.TestAnimalShelter) ... FAIL
#
# ======================================================================
# FAIL: test_read (__main__.TestAnimalShelter)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/tmp/ipykernel_1525515/510872355.py", line 30, in test_read
#     self.assertEqual(len(result), 1)
# AssertionError: 3 != 1
#
# ----------------------------------------------------------------------
# Ran 2 tests in 0.027s
#
# FAILED (failures=1)

# %%
import unittest
from crud_module import AnimalShelter
from bson.objectid import ObjectId

class TestAnimalShelter(unittest.TestCase):
    
    @classmethod
    def setUpClass(cls):
        cls.shelter = AnimalShelter(
            user='aacuser',
            password='SNHU1234',
            host='nv-desktop-services.apporto.com',
            port=31992,
            db='AAC',
            collection='animals'
        )
        cls.test_data = {"animal_id": "A123458", "name": "Max", "species": "Dog", "age": 2, "adopted": False}
        
    def setUp(self):
        # Ensure the test data has a unique _id
        self.test_data["_id"] = ObjectId()
        # Clean up the collection before each test
        self.shelter.collection.delete_many({"animal_id": "A123458"})

    def test_create(self):
        result = self.shelter.create(self.test_data)
        self.assertTrue(result)
            
    def test_read(self):
        self.shelter.create(self.test_data)
        result = self.shelter.read({"animal_id": "A123458"})
        self.assertEqual(len(result), 1)
        self.assertEqual(result[0]["name"], "Max")
            
if __name__ == '__main__':
    unittest.main(argv=[''], verbosity=2, exit=False)
# Out:
# test_create (__main__.TestAnimalShelter) ... ok
# test_read (__main__.TestAnimalShelter) ... ok
#
# ----------------------------------------------------------------------
# Ran 2 tests in 0.050s
#
# OK

# %%
import unittest
from crud_module import AnimalShelter
from bson.objectid import ObjectId

class TestAnimalShelter(unittest.TestCase):
    
    @classmethod
    def setUpClass(cls):
        cls.shelter = AnimalShelter(
            user='aacuser',
            password='SNHU1234',
            host='nv-desktop-services.apporto.com',
            port=31992,
            db='AAC',
            collection='animals'
        )
        cls.test_data = {"animal_id": "A123458", "name": "Max", "species": "Dog", "age": 2, "adopted": False}
        
    def setUp(self):
        # Ensure the test data has a unique _id
        self.test_data["_id"] = ObjectId()
        # Clean up the collection before each test
        self.shelter.collection.delete_many({"animal_id": "A123458"})

    def test_create(self):
        result = self.shelter.create(self.test_data)
        self.assertTrue(result)
            
    def test_read(self):
        self.shelter.create(self.test_data)
        result = self.shelter.read({"animal_id": "A123458"})
        self.assertEqual(len(result), 1)
        self.assertEqual(result[0]["name"], "Max")

    def test_update(self):
        self.shelter.create(self.test_data)
        update_data = {"name": "Maxwell"}
        result = self.shelter.update({"animal_id": "A123458"}, update_data)
        self.assertTrue(result)
        updated_doc = self.shelter.read({"animal_id": "A123458"})
        self.assertEqual(updated_doc[0]["name"], "Maxwell")

    def test_delete(self):
        self.shelter.create(self.test_data)
        result = self.shelter.delete({"animal_id": "A123458"})
        self.assertTrue(result)
        deleted_doc = self.shelter.read({"animal_id": "A123458"})
        self.assertEqual(len(deleted_doc), 0)

if __name__ == '__main__':
    unittest.main(argv=[''], verbosity=2, exit=False)
# Out:
# test_create (__main__.TestAnimalShelter) ... ok
# test_delete (__main__.TestAnimalShelter) ... ok
# test_read (__main__.TestAnimalShelter) ... ok
# test_update (__main__.TestAnimalShelter) ... ok
#
# ----------------------------------------------------------------------
# Ran 4 tests in 0.131s
#
# OK
